# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 透過金管局API收取可靠數據
#
# ## [Daily Monetary Statistics 每日金融數據](https://www.hkma.gov.hk/chi/data-publications-and-research/data-and-statistics/daily-monetary-statistics/)
# ## [API Detailed Documentation 應用程式介面詳細規格](https://apidocs.hkma.gov.hk/chi/documentation/market-data-and-statistics/daily-monetary-statistics/daily-figures-interbank-liquidity/)
# ## [API Documentation 使用說明](https://apidocs.hkma.gov.hk/documentation/)
# ## [JSON Output sample JSON格式示範](https://api.hkma.gov.hk/public/market-data-and-statistics/daily-monetary-statistics/daily-figures-monetary-base?pagesize=500&choose=end_of_date&from=2022-10&to=2024-07&sortorder=desc)

# %%
import numpy as np
import pandas as pd
import requests
import yfinance as yf

import matplotlib.pyplot as plt

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
apiFrom = '2022-01-01'
apiTo = '2024-10-20'

try:
    response = requests.get(f"https://api.hkma.gov.hk/public/market-data-and-statistics/daily-monetary-statistics/daily-figures-interbank-liquidity?pagesize=1000&choose=end_of_date&from={apiFrom}&to={apiTo}&sortorder=desc")
    if response.status_code==200 : print('Connect successfully!')
    data = response.json()
except Exception as e:
    print(e)
# Out:
# Connect successfully!

# %%
df_mbase = pd.DataFrame(data['result']['records'])
df_mbase = df_mbase.set_index('end_of_date')  
df_mbase.index = pd.to_datetime(df_mbase.index)
df_mbase = df_mbase.sort_values('end_of_date')
df_mbase
# Out:
#              cu_weakside  cu_strongside  disc_win_base_rate  hibor_overnight  \
# end_of_date
# 2022-01-03          7.85           7.75                0.50             0.03
# 2022-01-04          7.85           7.75                0.50             0.02
# 2022-01-05          7.85           7.75                0.50             0.02
# 2022-01-06          7.85           7.75                0.50             0.01
# 2022-01-07          7.85           7.75                0.50             0.01
# ...                  ...            ...                 ...              ...
# 2024-10-14          7.85           7.75                5.25             5.00
# 2024-10-15          7.85           7.75                5.25             4.60
# 2024-10-16          7.85           7.75                5.25             4.35
# 2024-10-17          7.85           7.75                5.25             4.25
# 2024-10-18          7.85           7.75                5.25             4.15
#
#              hibor_fixing_1m    twi  opening_balance  closing_balance  \
# end_of_date
# 2022-01-03           0.14929   95.1           377516           377516
# 2022-01-04           0.14298   95.5           377516           377516
# 2022-01-05           0.13655   95.4           377516           372511
# 2022-01-06           0.13512   95.5           372511           372511
# 2022-01-07           0.12976   95.4           372511           372511
# ...                      ...    ...              ...              ...
# 2024-10-14           4.37155  104.3            44809            47039
# 2024-10-15           4.42250  104.7            47039            44809
# 2024-10-16           4.36798  104.7            44809            44797
# 2024-10-17           4.32952  104.9            44797            44797
# 2024-10-18           4.29607  104.8            44797            45829
#
#             market_activities interest_payment  ... forex_trans_t4  \
# end_of_date                                     ...
# 2022-01-03                  0                0  ...           None
# 2022-01-04                  0                0  ...           None
# 2022-01-05                  0            -5005  ...           None
# 2022-01-06                  0                0  ...           None
# 2022-01-07                  0                0  ...           None
# ...                       ...              ...  ...            ...
# 2024-10-14                 +0               +0  ...           None
# 2024-10-15                 +0               +0  ...           None
# 2024-10-16                 +0              -12  ...           None
# 2024-10-17                 +0               +0  ...           None
# 2024-10-18                 +0               +0  ...           None
#
#             other_market_activities_t4  reversal_of_discount_window_t4  \
# end_of_date
# 2022-01-03                        None                            None
# 2022-01-04                        None                            None
# 2022-01-05                        None                            None
# 2022-01-06                        None                            None
# 2022-01-07                        None                            None
# ...                                ...                             ...
# 2024-10-14                        None                            None
# 2024-10-15                        None                            None
# 2024-10-16                        None                            None
# 2024-10-17                        None                            None
# 2024-10-18                        None                            None
#
#              interest_payment_issuance_efbn_t4  forecast_aggregate_bal_t4  \
# end_of_date
# 2022-01-03                                None                        NaN
# 2022-01-04                                None                        NaN
# 2022-01-05                                None                        NaN
# 2022-01-06                                None                        NaN
# 2022-01-07                                None                        NaN
# ...                                        ...                        ...
# 2024-10-14                                None                        NaN
# 2024-10-15                                None                        NaN
# 2024-10-16                                None                        NaN
# 2024-10-17                                None                        NaN
# 2024-10-18                                None                        NaN
#
#              forex_trans_u  other_market_activities_u  \
# end_of_date
# 2022-01-03               0                          0
# 2022-01-04               0                          0
# 2022-01-05               0                          0
# 2022-01-06               0                          0
# 2022-01-07               0                          0
# ...                    ...                        ...
# 2024-10-14              +0                         +0
# 2024-10-15              +0                         +0
# 2024-10-16              +0                         +0
# 2024-10-17              +0                         +0
# 2024-10-18              +0                         +0
#
#              reversal_of_discount_window_u interest_payment_issuance_efbn_u  \
# end_of_date
# 2022-01-03                               0                           -35035
# 2022-01-04                               0                           -35030
# 2022-01-05                               0                           -35030
# 2022-01-06                               0                           -35030
# 2022-01-07                               0                           -30029
# ...                                    ...                              ...
# 2024-10-14                              -0                             -934
# 2024-10-15                              -0                             -939
# 2024-10-16                              -0                             -939
# 2024-10-17                              -0                             -939
# 2024-10-18                              -0                             -918
#
#             forecast_aggregate_bal_u
# end_of_date
# 2022-01-03                    337480
# 2022-01-04                    337480
# 2022-01-05                    337480
# 2022-01-06                    337480
# 2022-01-07                    337479
# ...                              ...
# 2024-10-14                     43858
# 2024-10-15                     43858
# 2024-10-16                     43858
# 2024-10-17                     43858
# 2024-10-18                     43858
#
# [689 rows x 43 columns]

# %%
df_mbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 689 entries, 2022-01-03 to 2024-10-18
# Data columns (total 43 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   cu_weakside                                      689 non-null    float64
#  1   cu_strongside                                    689 non-null    float64
#  2   disc_win_base_rate                               689 non-null    float64
#  3   hibor_overnight                                  689 non-null    float64
#  4   hibor_fixing_1m                                  689 non-null    float64
#  5   twi                                              689 non-null    float64
#  6   opening_balance                                  689 non-null    int64
#  7   closing_balance                                  689 non-null    int64
#  8   market_activities                                689 non-null    object
#  9   interest_payment                                 689 non-null    object
#  10  discount_window_reversal                         689 non-null    object
#  11  discount_window_activities                       689 non-null    object
#  12  intraday_movements_of_aggregate_balance_at_0930  689 non-null    int64
#  13  intraday_movements_of_aggregate_balance_at_1000  689 non-null    int64
#  14  intraday_movements_of_aggregate_balance_at_1100  689 non-null    int64
#  15  intraday_movements_of_aggregate_balance_at_1200  689 non-null    int64
#  16  intraday_movements_of_aggregate_balance_at_1500  689 non-null    int64
#  17  intraday_movements_of_aggregate_balance_at_1600  689 non-null    int64
#  18  forex_trans_t1                                   689 non-null    object
#  19  other_market_activities_t1                       689 non-null    object
#  20  reversal_of_discount_window_t1                   689 non-null    object
#  21  interest_payment_issuance_efbn_t1                689 non-null    object
#  22  forecast_aggregate_bal_t1                        689 non-null    int64
#  23  forex_trans_t2                                   689 non-null    object
#  24  other_market_activities_t2                       689 non-null    object
#  25  reversal_of_discount_window_t2                   689 non-null    object
#  26  interest_payment_issuance_efbn_t2                689 non-null    object
#  27  forecast_aggregate_bal_t2                        689 non-null    int64
#  28  forex_trans_t3                                   689 non-null    object
#  29  other_market_activities_t3                       689 non-null    object
#  30  reversal_of_discount_window_t3                   689 non-null    object
#  31  interest_payment_issuance_efbn_t3                689 non-null    object
#  32  forecast_aggregate_bal_t3                        689 non-null    int64
#  33  forex_trans_t4                                   24 non-null     object
#  34  other_market_activities_t4                       24 non-null     object
#  35  reversal_of_discount_window_t4                   24 non-null     object
#  36  interest_payment_issuance_efbn_t4                24 non-null     object
#  37  forecast_aggregate_bal_t4                        24 non-null     float64
#  38  forex_trans_u                                    689 non-null    object
#  39  other_market_activities_u                        689 non-null    object
#  40  reversal_of_discount_window_u                    689 non-null    object
#  41  interest_payment_issuance_efbn_u                 689 non-null    object
#  42  forecast_aggregate_bal_u                         689 non-null    int64
# dtypes: float64(7), int64(12), object(24)
# memory usage: 236.8+ KB

# %% [markdown]
# # 下載相同時段time frame的恒指數據

# %%
df_HSI = yf.download('^HSI', start=apiFrom, end=apiTo, progress=False).droplevel('Ticker', axis=1)
df_HSI.index = df_HSI.index.strftime("%Y-%m-%d")
df_HSI.head(3)
# Out:
# YF.download() has changed argument auto_adjust default to True
# Price              Close          High           Low          Open      Volume
# Date
# 2022-01-03  23274.750000  23605.029297  23193.189453  23510.539062   734331100
# 2022-01-04  23289.839844  23439.300781  23146.890625  23400.619141  1760141200
# 2022-01-05  22907.250000  23323.769531  22851.500000  23323.769531  2768859000

# %% [markdown]
# # 合併相應的時段的基本利率Base Rate往 DataFrame

# %%
df_HSI['HKBaseRate'] = df_mbase['disc_win_base_rate']
df_HSI.head(3)
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2022-01-03  23274.750000  23605.029297  23193.189453  23510.539062
# 2022-01-04  23289.839844  23439.300781  23146.890625  23400.619141
# 2022-01-05  22907.250000  23323.769531  22851.500000  23323.769531
#
# Price           Volume  HKBaseRate
# Date
# 2022-01-03   734331100         0.5
# 2022-01-04  1760141200         0.5
# 2022-01-05  2768859000         0.5

# %% [markdown]
# # 比較Discount Window (貼現窗) Base Rate (基本利率) 與 恒指的收市價

# %%
fig, (ax0, ax1 ) = plt.subplots(2, 1, sharex=True, figsize=(16, 6))

ax0.plot(df_HSI.index.unique(), df_HSI['Close'])
ax1.plot(df_HSI.index.unique(), df_HSI['HKBaseRate'],color='orange' )
ax0.set_title("HSI Close Price")
ax1.set_title("HK /Base Rate")
# ax0.grid(True)
# ax1.grid(True)
ax0.legend(['HSI Close'])
ax1.legend(['Base Rate %'])
plt.show()

# %% [markdown]
# # 查看Correlation 的關係

# %%
df_HSI['Close'].corr(df_HSI['HKBaseRate'])
# Out:
# np.float64(-0.6878114971786082)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The FRED® API is a web service that allows developers to write programs and build applications that retrieve economic data from the FRED® and ALFRED® websites hosted by the Economic Research Division of the Federal Reserve Bank of St. Louis. Requests can be customized according to data source, release, category, series, and other preferences. <BR>
# [https://fred.stlouisfed.org/docs/api/fred/](https://fred.stlouisfed.org/docs/api/fred/)

# %%
# pip install fredapi

# %%
import os
from fredapi import Fred  # fred.search('Treasury')
#aa3bb655e3165ea72897c76eda4f2f57
# Place your FRED API Key to replace os.environ['FRED_API_KEY']
FRED_API_KEY ="aa3bb655e3165ea72897c76eda4f2f57"  #os.environ['FRED_API_KEY'] # Create free account https://fred.stlouisfed.org/
fred = Fred(api_key=FRED_API_KEY)

# %%
apiFrom = '2022-01-01'
apiTo = '2024-10-20'

# 10-Year Treasury Constant Maturity Minus 2-Year Treasury Constant Maturity (T10Y2Y)
T10Y2Y = fred.get_series('T10Y2Y',observation_start = apiFrom, observation_end = apiTo)

# Market Yield on U.S. Treasury Securities at 2-Year Constant Maturity
T2Y = fred.get_series('DGS2',observation_start = apiFrom, observation_end = apiTo)

# Market Yield on U.S. Treasury Securities at 10-Year Constant Maturity
T10Y = fred.get_series('DGS10',observation_start = apiFrom, observation_end = apiTo)

# %%
df_HSI['T10Y2Y'], df_HSI['T2Y'], df_HSI['T10Y'] = T10Y2Y, T2Y, T10Y

# %%
df_HSI.head(3)
# Out:
# Price              Close          High           Low          Open  \
# Date
# 2022-01-03  23274.750000  23605.029297  23193.189453  23510.539062
# 2022-01-04  23289.839844  23439.300781  23146.890625  23400.619141
# 2022-01-05  22907.250000  23323.769531  22851.500000  23323.769531
#
# Price           Volume  HKBaseRate  T10Y2Y   T2Y  T10Y
# Date
# 2022-01-03   734331100         0.5    0.85  0.78  1.63
# 2022-01-04  1760141200         0.5    0.89  0.77  1.66
# 2022-01-05  2768859000         0.5    0.88  0.83  1.71

# %%
fig, (ax0, ax1, ax2, ax3 ) = plt.subplots(4, 1, sharex=True, figsize=(16, 8))

ax0.plot(df_HSI.index.unique(), df_HSI['Close'])
ax1.plot(df_HSI.index.unique(), df_HSI['HKBaseRate'], color='orange' )
ax2.plot(df_HSI.index.unique(), df_HSI['T2Y'], color='red' )
ax2.plot(df_HSI.index.unique(), df_HSI['T10Y'], color='green' )
ax3.bar(df_HSI.index.unique(), df_HSI['T10Y2Y'], color='blue' )

ax0.set_title("HSI Close Price")
ax1.set_title("HK /Base Rate")
ax2.set_title("T10 and Y2Y")
ax3.set_title("T10 - Y2Y")

# ax0.grid(True)
# ax1.grid(True)
# ax2.grid(True)
# ax3.grid(True)

ax0.legend(['HSI Close'])
ax1.legend(['Base Rate %'])
ax2.legend([['Y2Y'],['T10']])
ax3.legend(['T10Y2Y'])
plt.show()

# %% [markdown]
# # 查看Correlation 的關係

# %%
df_HSI['Close'].corr(df_HSI['T10Y2Y'])
# Out:
# np.float64(0.4253568904648359)

# %%
df_HSI['LogRtn'] = np.log(df_HSI['Close'] / df_HSI['Close'].shift(1))

# %%
df_HSI['LogRtn'].plot.hist(bins=100, linewidth=0.5, edgecolor="white")
# Out:
# <Axes: ylabel='Frequency'>
