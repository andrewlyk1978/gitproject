# %%
import numpy as np
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ## 1. Create a Pandas DataFrame from a dictionary
# <pre>Given Input:
# data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#         'Age': [25, 30, 35, 40],
#         'Salary': [50000, 70000, 90000, 110000]}
#
# Desired Output:
#     Name	 Age	Salary
# 0	Alice	 25	 50000
# 1	Bob	   30	 70000
# 2	Charlie   35	 90000
# 3	David	 40	 110000
# </pre>

# %%
dataVoV = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'Salary': [50000, 70000, 90000, 110000]}
AaaDFaaA= pd.DataFrame(data=dataVoV)

print(AaaDFaaA,"\nType(dataVoV):", type(dataVoV))
# Out:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   70000
# 2  Charlie   35   90000
# 3    David   40  110000
# Type(dataVoV): <class 'dict'>

# %% [markdown]
# ## 2. Load a CSV file into a Pandas DataFrame
# Given iris CSV dataset: iris.csv

# %%
Df_iris=pd.read_csv("iris.csv")

# %% [markdown]
# ## 3. View the first, last and sample of 2 rows of a DataFrame
# Given the iris df above

# %%
Df_iris.head(2)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa

# %%
Df_iris.tail(2)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %%
Df_iris.sample(2)
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 65          6.7         3.1          4.4         1.4  Iris-versicolor
# 71          6.1         2.8          4.0         1.3  Iris-versicolor

# %% [markdown]
# ## 4. Get basic information and descriptive statistics about a DataFrame

# %%
# info
Df_iris.info
# Out:
# <bound method DataFrame.info of      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
Df_iris.value_counts()
# Out:
# SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 4.9          3.1         1.5          0.1         Iris-setosa        3
# 5.8          2.7         5.1          1.9         Iris-virginica     2
#              4.0         1.2          0.2         Iris-setosa        1
# 5.9          3.0         4.2          1.5         Iris-versicolor    1
# 6.2          3.4         5.4          2.3         Iris-virginica     1
#                                                                     ..
# 5.5          2.3         4.0          1.3         Iris-versicolor    1
#              2.4         3.7          1.0         Iris-versicolor    1
#                          3.8          1.1         Iris-versicolor    1
#              2.5         4.0          1.3         Iris-versicolor    1
# 7.9          3.8         6.4          2.0         Iris-virginica     1
# Name: count, Length: 147, dtype: int64

# %%
Df_iris.describe(include='O')

'''

上に示したように、describe()はデフォルトでは数値データ（int型やfloat型など）の基本統計量を表示しますが、引数にinclude='O'（大文字のオーです）を指定することで、オブジェクトデータ（str型など）に関する情報を表示できます。このとき表示されるのは、上から、データ数（count）、重複を排除したデータ数（unique）、最も多く含まれるデータ（top）、そのデータが含まれる個数（freq）です。
https://qiita.com/0NE_shoT_/items/bf700662b2c36aee0f8e
data.describe(include='O')
describe(include=['O']).jpg
さらに、引数にinclude='all'を指定することで、数値データとオブジェクトデータに関する情報を合わせて表示することができます

'''
# Out:
# "\n\n上に示したように、describe()はデフォルトでは数値データ（int型やfloat型など）の基本統計量を表示しますが、引数にinclude='O'（大文字のオーです）を指定することで、オブジェクトデータ（str型など）に関する情報を表示できます。このとき表示されるのは、上から、データ数（count）、重複を排除したデータ数（unique）、最も多く含まれるデータ（top）、そのデータが含まれる個数（freq）です。\nhttps://qiita.com/0NE_shoT_/items/bf700662b2c36aee0f8e\ndata.describe(include='O')\ndescribe(include=['O']).jpg\nさらに、引数にinclude='all'を指定することで、数値データとオブジェクトデータに関する情報を合わせて表示することができます\n\n"

# %%
Df_iris.Name.value_counts().values

# df.groupby('colA')['colA'].count()  https://segmentfault.com/q/1010000043270370
# Out:
# array([50, 50, 50], dtype=int64)

# %%
Df_iris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
Df_iris.groupby('SepalLength')[['SepalLength','PetalLength','PetalWidth','Name']]

#.value_counts().values

#SepalWidth  PetalLength  PetalWidth  Name

# %%
Df_iris.groupby('SepalLength')[['PetalLength','PetalWidth','Name']].sum().reset_index()
# Out:
#     SepalLength  PetalLength  PetalWidth  \
# 0           4.3          1.1         0.1
# 1           4.4          4.0         0.6
# 2           4.5          1.3         0.3
# 3           4.6          5.3         0.9
# 4           4.7          2.9         0.4
# 5           4.8          7.9         1.0
# 6           4.9         13.7         3.2
# 7           5.0         18.4         4.3
# 8           5.1         15.5         3.6
# 9           5.2          8.3         1.9
# 10          5.3          1.5         0.2
# 11          5.4         12.2         3.1
# 12          5.5         22.6         6.3
# 13          5.6         25.2         8.5
# 14          5.7         28.7         8.8
# 15          5.8         28.5         9.8
# 16          5.9         14.1         5.1
# 17          6.0         27.9         9.0
# 18          6.1         28.5         8.5
# 19          6.2         19.0         6.9
# 20          6.3         46.2        16.3
# 21          6.4         36.1        13.1
# ...

# %% [markdown]
# (df_1920.groupby('team')[['Total_pts','Total_reb','Total_ast']].
#             .sort_values(by=(['Total_pts','Total_reb','Total_ast']),
#             ascending=[0,0,1]).head())

# %%
Df_iris.Name.value_counts().axes
# Out:
# [Index(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype='object', name='Name')]

# %%
# basic stats, min, max, mean, std ...



Df_iris.describe(percentiles=[0.05,0.25,0.75,0.95,0.99],include='all')
# Out:
#         SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# count    150.000000  150.000000   150.000000  150.000000          150
# unique          NaN         NaN          NaN         NaN            3
# top             NaN         NaN          NaN         NaN  Iris-setosa
# freq            NaN         NaN          NaN         NaN           50
# mean       5.843333    3.054000     3.758667    1.198667          NaN
# std        0.828066    0.433594     1.764420    0.763161          NaN
# min        4.300000    2.000000     1.000000    0.100000          NaN
# 5%         4.600000    2.345000     1.300000    0.200000          NaN
# 25%        5.100000    2.800000     1.600000    0.300000          NaN
# 50%        5.800000    3.000000     4.350000    1.300000          NaN
# 75%        6.400000    3.300000     5.100000    1.800000          NaN
# 95%        7.255000    3.800000     6.100000    2.300000          NaN
# ...

# %%
Df_iris.describe(percentiles=[0.05,0.25,0.75,0.95,0.99],include='O')
# Out:
#                Name
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
Df_iris['Name'].tolist()
# Out:
# ['Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-setosa',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
#  'Iris-versicolor',
# ...

# %%
result_iris=Df_iris.columns
result_iris
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %%
print(Df_iris.columns.tolist())
# Out:
# ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name']

# %% [markdown]
# https://saturncloud.io/blog/how-to-get-a-list-from-a-pandas-dataframe-column/
#
# How to Get a List from a Pandas Dataframe Column
# As a data scientist or software engineer you may often need to extract a list of values from a specific column of a Pandas dataframe This is a common task in data analysis and machine learning and can be easily accomplished using a few lines of code in Python

# %% [markdown]
# ## 5. Get all statistics about a DataFrame

# %%
# show all columns stats
Df_iris.describe(include='all')
# Out:
#         SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# count    150.000000  150.000000   150.000000  150.000000          150
# unique          NaN         NaN          NaN         NaN            3
# top             NaN         NaN          NaN         NaN  Iris-setosa
# freq            NaN         NaN          NaN         NaN           50
# mean       5.843333    3.054000     3.758667    1.198667          NaN
# std        0.828066    0.433594     1.764420    0.763161          NaN
# min        4.300000    2.000000     1.000000    0.100000          NaN
# 25%        5.100000    2.800000     1.600000    0.300000          NaN
# 50%        5.800000    3.000000     4.350000    1.300000          NaN
# 75%        6.400000    3.300000     5.100000    1.800000          NaN
# max        7.900000    4.400000     6.900000    2.500000          NaN

# %% [markdown]
# ## 6. Select multiple columns by column name of a DataFrame

# %%
# select 'SepalLength','SepalWidth','Name'

# %%
result_iris=Df_iris.columns
result_iris
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %%
Df_iris.index[0]
# Out:
# 0

# %%
#df_hsi.at[df_hsi.index[4],'Open']
Df_iris[['SepalLength', 'SepalWidth', 'Name']]
# Out:
#      SepalLength  SepalWidth            Name
# 0            5.1         3.5     Iris-setosa
# 1            4.9         3.0     Iris-setosa
# 2            4.7         3.2     Iris-setosa
# 3            4.6         3.1     Iris-setosa
# 4            5.0         3.6     Iris-setosa
# ..           ...         ...             ...
# 145          6.7         3.0  Iris-virginica
# 146          6.3         2.5  Iris-virginica
# 147          6.5         3.0  Iris-virginica
# 148          6.2         3.4  Iris-virginica
# 149          5.9         3.0  Iris-virginica
#
# [150 rows x 3 columns]

# %% [markdown]
# ## 7. Select multiple columns by index of a DataFrame

# %%
# select df all rows from column [0,1,4]
Df_iris.iloc[:,[0,1,4]]


# first 2 rows of [0,1,4] columns
#Df_iris.iloc[:,[0,1,4]]  #前面Row 後面Columns
#Df_iris.iloc[[0,1,2,4],[0,1,4]]
# Out:
#      SepalLength  SepalWidth            Name
# 0            5.1         3.5     Iris-setosa
# 1            4.9         3.0     Iris-setosa
# 2            4.7         3.2     Iris-setosa
# 3            4.6         3.1     Iris-setosa
# 4            5.0         3.6     Iris-setosa
# ..           ...         ...             ...
# 145          6.7         3.0  Iris-virginica
# 146          6.3         2.5  Iris-virginica
# 147          6.5         3.0  Iris-virginica
# 148          6.2         3.4  Iris-virginica
# 149          5.9         3.0  Iris-virginica
#
# [150 rows x 3 columns]

# %%
print(Df_iris.columns)
# Out:
# Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')

# %%
print(Df_iris.axes)
# Out:
# [RangeIndex(start=0, stop=150, step=1), Index(['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Name'], dtype='object')]

# %% [markdown]
# ## 8. Select a subset of rows and columns of a DataFrame

# %%
# first 2 rows of [0,1,4] columns
Df_iris.iloc[0:2,[0,1,4]]  #前面Row 後面Columns


#Df_iris.iloc[[0:1],[0,1,4]]
# Out:
#    SepalLength  SepalWidth         Name
# 0          5.1         3.5  Iris-setosa
# 1          4.9         3.0  Iris-setosa

# %%
Df_iris.iloc[[0,1,2,4],[0,1,4]]  #前面Row 後面Columna
# Out:
#    SepalLength  SepalWidth         Name
# 0          5.1         3.5  Iris-setosa
# 1          4.9         3.0  Iris-setosa
# 2          4.7         3.2  Iris-setosa
# 4          5.0         3.6  Iris-setosa

# %%
# last 2 rows of [0,1,4] columns
Df_iris.iloc[-4:-2,[0,1,4]]
# Out:
#      SepalLength  SepalWidth            Name
# 146          6.3         2.5  Iris-virginica
# 147          6.5         3.0  Iris-virginica

# %%
Df_iris.iloc[:2,[0,1,4]]
# Out:
#    SepalLength  SepalWidth         Name
# 0          5.1         3.5  Iris-setosa
# 1          4.9         3.0  Iris-setosa

# %% [markdown]
# ## 9. Filter a DataFrame by condition

# %%
# The most proper way is using .loc
# select all rows 'PetalLength' > 6.4


# This is also OK for simple condition without other function
# try select all rows 'PetalLength' > 6.4 using other method

# %%
Df_iris.loc[Df_iris['PetalLength']>6.4]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 105          7.6         3.0          6.6         2.1  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica

# %%
Df_iris[Df_iris['PetalLength']>6.4]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 105          7.6         3.0          6.6         2.1  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica

# %% [markdown]
# ## 10. Filter a DataFrame by condition

# %%
# The quickest way is using indexed location
# use iloc to filter 'PetalLength' > 6.4

# %% [markdown]
# ## 11. Sort a DataFrame by a column

# %%
# sort df by 'SepalLength' 
Df_iris.sort_values(by=['SepalLength'])
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 13           4.3         3.0          1.1         0.1     Iris-setosa
# 42           4.4         3.2          1.3         0.2     Iris-setosa
# 38           4.4         3.0          1.3         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 41           4.5         2.3          1.3         0.3     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica
# 131          7.9         3.8          6.4         2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 12. Sort a DataFrame by multiple column

# %%
# sort 'SepalLength','SepalWidth', by desc and desc order, print first 10 rows
Df_iris.sort_values(by=['SepalLength','SepalWidth'],ascending=True).iloc[[1,2],[0,3]]


#.head(10)
# Out:
#     SepalLength  PetalWidth
# 8           4.4         0.2
# 38          4.4         0.2

# %%
(Df_iris.sort_values(by=['SepalLength','SepalWidth'],ascending=True)).iloc[-10:,:]
#Df_iris.iloc[:2,[0,1,4]]
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 125          7.2         3.2          6.0         1.8  Iris-virginica
# 109          7.2         3.6          6.1         2.5  Iris-virginica
# 107          7.3         2.9          6.3         1.8  Iris-virginica
# 130          7.4         2.8          6.1         1.9  Iris-virginica
# 105          7.6         3.0          6.6         2.1  Iris-virginica
# 118          7.7         2.6          6.9         2.3  Iris-virginica
# 122          7.7         2.8          6.7         2.0  Iris-virginica
# 135          7.7         3.0          6.1         2.3  Iris-virginica
# 117          7.7         3.8          6.7         2.2  Iris-virginica
# 131          7.9         3.8          6.4         2.0  Iris-virginica

# %% [markdown]
# ## 13. Group a DataFrame by a column and calculate mean
# Group DataFrame using a mapper or by a Series of columns

# %%
# return mean of 3 species' SepalLength	SepalWidth	PetalLength	PetalWidth
#Df_iris.mean()
Df_iris[['SepalLength','SepalWidth','PetalLength','PetalWidth']].mean().reset_index()

#Df_iris.isna()
# Out:
#          index         0
# 0  SepalLength  5.843333
# 1   SepalWidth  3.054000
# 2  PetalLength  3.758667
# 3   PetalWidth  1.198667

# %%
Df_iris.groupby('SepalLength')[['SepalWidth','PetalLength','PetalWidth']].agg('mean').reset_index()
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth
# 0           4.3    3.000000     1.100000    0.100000
# 1           4.4    3.033333     1.333333    0.200000
# 2           4.5    2.300000     1.300000    0.300000
# 3           4.6    3.325000     1.325000    0.225000
# 4           4.7    3.200000     1.450000    0.200000
# 5           4.8    3.180000     1.580000    0.200000
# 6           4.9    2.866667     2.283333    0.533333
# 7           5.0    3.120000     1.840000    0.430000
# 8           5.1    3.477778     1.722222    0.400000
# 9           5.2    3.425000     2.075000    0.475000
# 10          5.3    3.700000     1.500000    0.200000
# 11          5.4    3.550000     2.033333    0.516667
# 12          5.5    2.842857     3.228571    0.900000
# 13          5.6    2.816667     4.200000    1.416667
# 14          5.7    3.100000     3.587500    1.100000
# 15          5.8    2.885714     4.071429    1.400000
# 16          5.9    3.066667     4.700000    1.700000
# ...

# %%
Df_iris.notnull()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0           True        True         True        True  True
# 1           True        True         True        True  True
# 2           True        True         True        True  True
# 3           True        True         True        True  True
# 4           True        True         True        True  True
# ..           ...         ...          ...         ...   ...
# 145         True        True         True        True  True
# 146         True        True         True        True  True
# 147         True        True         True        True  True
# 148         True        True         True        True  True
# 149         True        True         True        True  True
#
# [150 rows x 5 columns]

# %%
# SELECT state, count(name)
#FROM df
#GROUP BY state
#ORDER BY state
#df.groupby(["Company"])["MPG"].agg(['max','min','mean','count','std','median'])


Df_iris.groupby(['Name']).agg(['max','min','mean','count','std','median'])
# Out:
#                 SepalLength                                    SepalWidth  \
#                         max  min   mean count       std median        max
# Name
# Iris-setosa             5.8  4.3  5.006    50  0.352490    5.0        4.4
# Iris-versicolor         7.0  4.9  5.936    50  0.516171    5.9        3.4
# Iris-virginica          7.9  4.9  6.588    50  0.635880    6.5        3.8
#
#                                    ... PetalLength                         \
#                  min   mean count  ...        mean count       std median
# Name                               ...
# Iris-setosa      2.3  3.418    50  ...       1.464    50  0.173511   1.50
# Iris-versicolor  2.0  2.770    50  ...       4.260    50  0.469911   4.35
# Iris-virginica   2.2  2.974    50  ...       5.552    50  0.551895   5.55
#
#                 PetalWidth
#                        max  min   mean count       std median
# Name
# Iris-setosa            0.6  0.1  0.244    50  0.107210    0.2
# ...

# %%
Df_iris.groupby(['Name'])[[('SepalLength'),('SepalWidth'),('PetalLength'),('PetalWidth')]].mean()
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa            5.006       3.418        1.464       0.244
# Iris-versicolor        5.936       2.770        4.260       1.326
# Iris-virginica         6.588       2.974        5.552       2.026

# %%
Df_iris.groupby(['Name'])[[('SepalLength'),('SepalWidth'),('PetalLength'),('PetalWidth')]].agg(['mean'])
# Out:
#                 SepalLength SepalWidth PetalLength PetalWidth
#                        mean       mean        mean       mean
# Name
# Iris-setosa           5.006      3.418       1.464      0.244
# Iris-versicolor       5.936      2.770       4.260      1.326
# Iris-virginica        6.588      2.974       5.552      2.026

# %%
Df_iris.groupby(['Name'])

# %%
# return median of 3 species' SepalLength	SepalWidth	PetalLength	PetalWidth

# %%
Df_iris.groupby(['Name'])[[('SepalLength'),('SepalWidth'),('PetalLength'),('PetalWidth')]].median().reset_index()
# Out:
#               Name  SepalLength  SepalWidth  PetalLength  PetalWidth
# 0      Iris-setosa          5.0         3.4         1.50         0.2
# 1  Iris-versicolor          5.9         2.8         4.35         1.3
# 2   Iris-virginica          6.5         3.0         5.55         2.0

# %%
Df_iris.groupby(['Name'])[[('SepalLength'),('SepalWidth'),('PetalLength'),('PetalWidth')]].std().reset_index()
# Out:
#               Name  SepalLength  SepalWidth  PetalLength  PetalWidth
# 0      Iris-setosa     0.352490    0.381024     0.173511    0.107210
# 1  Iris-versicolor     0.516171    0.313798     0.469911    0.197753
# 2   Iris-virginica     0.635880    0.322497     0.551895    0.274650

# %%
# return SD of 3 species' SepalLength	SepalWidth	PetalLength	PetalWidth

# %% [markdown]
# ## 14. Add a new column to a DataFrame

# %%
# The most proper way, is to add column followed df.index
# use df.loc[df.index, 'Volume'] 
# np.pi * 'SepalWidth'**2 * 'PetalLength'
# df.sample(3)                                    
#loc 方法和 iloc 方法一样，可以索引 DataFrame 数据，一般是通过 
#data.loc[index, col] = value 来进行赋值，这里利用：来索引全部行再进行赋值。#

# %%
Df_iris.loc[Df_iris.index,'Volume']=np.pi*Df_iris['SepalWidth']**2*Df_iris['PetalLength']

# %%
Df_iris
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name  \
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
#          Volume
# 0     53.878314
# 1     39.584067
# 2     41.820881
# 3     45.286058
# 4     57.001057
# ..          ...
# ...

# %% [markdown]
# ## 15. Rename an existing column

# %%
# Rename 'Name' as 'Species'

# %% [markdown]
# ## 16. Drop a column

# %%
#drop 'Volume'

# %% [markdown]
# ## 17. Data cleaning - dropna, fillna
# <pre>Given Input:
# data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Elle'],
#         'Salary': [50000, 70000, 60000, 90000, np.NaN]}
# payroll = pd.DataFrame(data)
#
# Requirement:
# 1. Drop NaN
# 2. Fill NaN with zero
# 3. Fill NaN with mean
# 4. Fill NaN with median</pre>

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Elle'],
        'Salary': [50000, 70000, 60000, 90000, np.NaN]}
#

# %%
# fill nan with mean

# %%
# fill nan with median

# %%
# use dropna

# %%
# fill nan with 0

# %% [markdown]
# ## 18. Find the unique value and number of unique value
# <pre>In Iris DF, find :
# 1. Unique Iris species names
# 2. How many kinds of species
# 3. How many sample in each species</pre>

# %%
Df_iris['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
Df_iris.groupby(['Name']).agg(['count'])
# Out:
#                 SepalLength SepalWidth PetalLength PetalWidth Volume
#                       count      count       count      count  count
# Name
# Iris-setosa              50         50          50         50     50
# Iris-versicolor          50         50          50         50     50
# Iris-virginica           50         50          50         50     50

# %%
Df_iris['Name'].value_counts()
# Out:
# Name
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## 19. Replace values in a DataFrame
# <pre>Change the Species names in iris DF:
# Given Input:
# df = df.replace({'Iris-setosa': 'Setosa',
#             'Iris-versicolor': 'Versicolor',
#            'Iris-virginica':'Virginica'})
#
# Desired Output:
# ['Setosa', 'Versicolor', 'Virginica']</pre>

# %%
df = df.replace({'Iris-setosa': 'Setosa', 
            'Iris-versicolor': 'Versicolor',
           'Iris-virginica':'Virginica'})
# unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[298], line 1
# ----> 1 df = df.replace({'Iris-setosa': 'Setosa',
#       2             'Iris-versicolor': 'Versicolor',
#       3            'Iris-virginica':'Virginica'})
#       4 # unique
#
# NameError: name 'df' is not defined

# %%
Df_iris['Name']=Df_iris['Name'].replace({'Iris-setosa': 'Setosa', 
            'Iris-versicolor': 'Versicolor',
           'Iris-virginica':'Virginica'})

# %% [markdown]
# ## 20. Replace values where the condition is False
# <pre>Let's assume a species is large if its SepalLength is bigger
# than mean. Create a new column 'LargeSpecies' and fill with
# Boolean to identify if the species belong to LargeSpecies.
#
# You may create a column to fill with False first.
# $> df.loc[df.index, 'LargeSpecies'] = False
# </pre>

# %%
Df_iris['SepalLength'].mean()

# %%
Df_iris.loc[Df_iris.index, 'LargeSpecies'] = False
Df_iris.sample(2)

# %%
''' df['LargeSpecies'] = df['LargeSpecies'].where(
    df['SepalLength']<df['SepalLength'].mean(), True)
df.sample(5)
'''

# %%
Df_iris['SepalLength'].mean()

# %%
Df_iris[(Df_iris['SepalLength']<Df_iris['SepalLength'].mean())]

# %%
Df_iris['LargeSpecies']=np.where( Df_iris['SepalLength']<Df_iris['SepalLength'].mean(), True, False)
Df_iris.sample(20)

# %% [markdown]
# ## 21. Replace values where the condition is True
# <pre>df.mask() is the opposite of df.where()
# df.mask(cond, other) will replace value with other if cond is True.
#
# Let's create another column
# df.loc[df.index, 'SmallSpecies'] = False
# Replace the Boolean to True if 'SepalLength' smaller and equal
# to mean.
# </pre>

# %%
print(int(np.random.randint(3,15,size=1)))

# %%
Df_iris.loc[Df_iris.index, 'SmallSpecies'] = 0

Df_iris['SmallSpecies']=Df_iris['SmallSpecies'].mask(Df_iris['SmallSpecies']<=Df_iris['SmallSpecies'].mean(),True)

Df_iris.sample(int(np.random.randint(3,15,size=1)))

# %%
#Df_iris['SmallSpecies']

# %%
# Double check. Add up the LargeSpecies(True) and SmallSpecies(True)

# %% [markdown]
# ## 22. Fill values with numpy.where
# <pre>Requirement:
# 1. Create new column 'SampleSize'
# 2. Fill it 'Large' if SepalLength > mean, else 'Small'.
#
# Given Input:
# Drop column 'LargeSpecies' and 'SmallSpecies'
# df = df.drop(['LargeSpecies','SmallSpecies'], axis=1)
#
# Desired Output:
#
# </pre>

# %%
Df_iris = Df_iris.drop(['LargeSpecies','SmallSpecies'], axis=1)
Df_iris.sample(2)

# %%
df['SampleSize'].value_counts()

# %%
df.sample(3)

# %%
Df_iris.loc[Df_iris.index,'SamplesSize']=np.where(Df_iris['SepalLength']<Df_iris['SepalLength'].mean(),'Large','Small')
Df_iris.sample(20)


#Df_iris.loc[Df_iris.index, 'LargeSpecies'] = False
#Df_iris.sample(2)

# Fill it 'Large' if SepalLength > mean, else 'Small

#Df_iris['LargeSpecies']=np.where( Df_iris['SepalLength']<Df_iris['SepalLength'].mean(), True, False)
#Df_iris.sample(20)

# %%
Df_iris['SamplesSize'].value_counts()

# %% [markdown]
# ## 23. Change DataFrame column postion

# %%
'Species', 'SepalLength', 'SepalWidth',
         'PetalLength', 'PetalWidth', 'SampleSize'

# %%
Df_iris=Df_iris[['Name', 'SepalLength', 'SepalWidth',
         'PetalLength', 'PetalWidth', 'SamplesSize']]


#SepalLength	SepalWidth	PetalLength	PetalWidth	Name	LargeSpecies	SmallSpecies	SamplesSize

# %%
Df_iris.sample(3)

# %% [markdown]
# ## 24. Apply a function on a column
# Let's change the data in SampleSize field to Uppercase

# %%
Df_iris['SampleSize'] =Df_iris['SampleSize'].apply(lambda x: x.upper())

# %%
Df_iris.sample(5)

# %%
Df_iris.head(5)

# %%
def uppercase(x): 
     return x.upper()

Df_iris['SamplesSize'].apply(uppercase)

# %% [markdown]
# ## 25. Map dict or function on a column

# %%
Df_iris['SampleSize'] = Df_iris['SampleSize'].map({'SMALL': 'Small Iris', 
                                         'LARGE': 'Large Iris'})

# %% [markdown]
# df.sample(5)

# %%
Df_iris['SamplesSize']=Df_iris['SamplesSize'].map({'SMALL':'Small Iris','LARGE':'Large Iris'})

Df_iris.sample(5)

# %% [markdown]
# ## 26. Map a function on multiple column or whole DF

# %%
Df_iris[['SepalLength','SepalWidth','PetalLength','PetalWidth']] = Df_iris[[
    'SepalLength','SepalWidth','PetalLength','PetalWidth']].map(lambda x: str(x) )

# %%
Df_iris.sample(5)

# %%
Falon_Dog=pd.DataFrame( { 'num_legs':[2,4,4,6],'num_wings':[2,0,0,0]}, index=['falon','dog','cat','ant'])
Falon_Dog

# %%
Falon_Dog.value_counts()

# %%
Falon_Dog.value_counts().to_frame()

# %%
#df.groupby(["Company"])["MPG"].agg(['max','min','mean','count','std','median'])  
#Df_iris.groupby(['Name'])[[('SepalLength'),('SepalWidth'),('PetalLength'),('PetalWidth')]].mean()

#Falon_Dog.groupby(['num_legs'])['num_wings'].agg(['mean'])
Falon_Dog.groupby(['num_legs'])['num_wings']
