# %%
# pip install seaborn --upgrade

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import datetime as dt
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import warnings
#warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',None)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <style>.container { width:100% !important; }</style>

# %%
df=pd.read_csv('LifeExpectancy.csv')
df.head(5)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %% [markdown]
# ## Replacing the Null Values with mean values of the data

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(missing_values=np.nan,strategy='mean',fill_value=None)
df['Life expectancy ']=imputer.fit_transform(df[['Life expectancy ']])
df['Adult Mortality']=imputer.fit_transform(df[['Adult Mortality']])
df['Alcohol']=imputer.fit_transform(df[['Alcohol']])
df['Hepatitis B']=imputer.fit_transform(df[['Hepatitis B']])
df[' BMI ']=imputer.fit_transform(df[[' BMI ']])
df['Polio']=imputer.fit_transform(df[['Polio']])
df['Total expenditure']=imputer.fit_transform(df[['Total expenditure']])
df['Diphtheria ']=imputer.fit_transform(df[['Diphtheria ']])
df['GDP']=imputer.fit_transform(df[['GDP']])
df['Population']=imputer.fit_transform(df[['Population']])
df[' thinness  1-19 years']=imputer.fit_transform(df[[' thinness  1-19 years']])
df[' thinness 5-9 years']=imputer.fit_transform(df[[' thinness 5-9 years']])
df['Income composition of resources']=imputer.fit_transform(df[['Income composition of resources']])
df['Schooling']=imputer.fit_transform(df[['Schooling']])

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2938.000000      2938.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.507640       124.080302     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.200000        74.000000       0.000000
# 50%    2008.000000         72.000000       144.000000       3.000000
# 75%    2012.000000         75.600000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2938.000000             2938.000000  2938.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       3.916288             1987.914858    22.586855   11467.272489
# ...

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.drop(['Status','Country'],axis=1).corr(),annot=True,cmap='Greens')
plt.show()

# %% [markdown]
# ## Life expectancy

# %%
fig=px.histogram(df,x='Life expectancy ')
fig.show()
# Out:
# <div>                            <div id="8a2ee7ce-ac9a-4ae5-b15b-dd05a1af3378" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a2ee7ce-ac9a-4ae5-b15b-dd05a1af3378")) {                    Plotly.newPlot(                        "8a2ee7ce-ac9a-4ae5-b15b-dd05a1af3378",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Life expectancy =%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[65.0,59.9,59.9,59.5,59.2,58.8,58.6,58.1,57.5,57.3,57.3,57.0,56.7,56.2,55.3,54.8,77.8,77.5,77.2,76.9,76.6,76.2,76.1,75.3,75.9,74.2,73.5,73.0,72.8,73.3,73.6,72.6,75.6,75.4,75.3,75.1,74.9,
# ...

# %% [markdown]
# ## DEVELOPED COUNTRIES HAS MAXIMUM LIFE EXPENTANCY

# %%
fig=px.violin(df,x='Status',y='Life expectancy ',color='Status',
              box=True,title='Life expectancy Based on Countries status')
fig.show()
# Out:
# <div>                            <div id="aa1ab649-345f-47d9-9da1-930f04e10069" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aa1ab649-345f-47d9-9da1-930f04e10069")) {                    Plotly.newPlot(                        "aa1ab649-345f-47d9-9da1-930f04e10069",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"Status=%{x}\u003cbr\u003eLife expectancy =%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Developing","marker":{"color":"#636efa"},"name":"Developing","offsetgroup":"Developing","orientation":"v","scalegroup":"True","showlegend":true,"x":["Developing","Developing","Developing","Developing","Developing","Developing","Developing","Developing","Developing","Developing","Developing","Develo
# ...

# %% [markdown]
# ## Country wise Life Expectancy over Years

# %%
fig=px.line(df.sort_values(by='Year'),x='Year',y='Life expectancy ',
            animation_frame='Country',animation_group='Year',color='Country',
            markers=True,title='<b> Country wise Life Expectancy over Years')
fig.show()
# Out:
# <div>                            <div id="410a8396-f2ba-41c9-85c1-a4d443711e01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("410a8396-f2ba-41c9-85c1-a4d443711e01")) {                    Plotly.newPlot(                        "410a8396-f2ba-41c9-85c1-a4d443711e01",                        [{"hovertemplate":"Country=Zimbabwe\u003cbr\u003eYear=%{x}\u003cbr\u003eLife expectancy =%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"legendgroup":"Zimbabwe","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Zimbabwe","orientation":"v","showlegend":true,"x":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,20
# ...

# %% [markdown]
# ## Life Expectancy Versus Adult Mortality

# %%
px.scatter(df,y='Adult Mortality',x='Life expectancy ',color='Country',
           size='Life expectancy ', opacity=0.6,
           title='<b> Life Expectancy Versus Adult Mortality')
# Out:
# <div>                            <div id="083321ef-0a43-46ea-95c1-f92900c2de9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("083321ef-0a43-46ea-95c1-f92900c2de9f")) {                    Plotly.newPlot(                        "083321ef-0a43-46ea-95c1-f92900c2de9f",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eLife expectancy =%{marker.size}\u003cbr\u003eAdult Mortality=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","opacity":0.6,"size":[65.0,59.9,59.9,59.5,59.2,58.8,58.6,58.1,57.5,57.3,57.3,57.0,56.7,56.2,55.3,54.8],"sizemode":"area","sizeref":0.2225,"symbol":"circle"},"mode":"markers","name":"Afghanistan","showlegend":true,"x":[65.0,59.9,59.9,59.5,59.2,58.8,58.6,
# ...

# %% [markdown]
# ## Life Expectancy Versus Percentage expenditure

# %%
px.scatter(df,x='Life expectancy ',y='percentage expenditure',color='Country',
           size='Year',title='<b> Life Expectancy Versus Percentage expenditure')
# Out:
# <div>                            <div id="4dce7fd0-f6f8-4a20-b283-6da6fe477a76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dce7fd0-f6f8-4a20-b283-6da6fe477a76")) {                    Plotly.newPlot(                        "4dce7fd0-f6f8-4a20-b283-6da6fe477a76",                        [{"hovertemplate":"Country=Afghanistan\u003cbr\u003eLife expectancy =%{x}\u003cbr\u003epercentage expenditure=%{y}\u003cbr\u003eYear=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","marker":{"color":"#636efa","size":[2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000],"sizemode":"area","sizeref":5.0375,"symbol":"circle"},"mode":"markers","name":"Afghanistan","showlegend":true,"x":[65.0,59.9,59.9,59.5
# ...

# %% [markdown]
# ## Life Expectancy Versus Infant Deaths of Countries in every Year

# %%
px.scatter(df.sort_values(by='Year'), y='infant deaths', x='Life expectancy ', 
           size='Year',color='Country', opacity=0.6,
           title='<b>Life Expectancy Versus Infant Deaths of Countries in every Year')
# Out:
# <div>                            <div id="8d582ac4-cdef-4a91-b06e-e61678ead6d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d582ac4-cdef-4a91-b06e-e61678ead6d4")) {                    Plotly.newPlot(                        "8d582ac4-cdef-4a91-b06e-e61678ead6d4",                        [{"hovertemplate":"Country=Zimbabwe\u003cbr\u003eLife expectancy =%{x}\u003cbr\u003einfant deaths=%{y}\u003cbr\u003eYear=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zimbabwe","marker":{"color":"#636efa","opacity":0.6,"size":[2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015],"sizemode":"area","sizeref":5.0375,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","showlegend":true,"x":[46.0,45.3,44.8,44.5,44.
# ...

# %%
## Life expectancy vs Schooling vs Total expenditure

# %%
px.scatter_3d(df.sort_values(by='Year'),y='Schooling',x='Life expectancy ',
              z='Total expenditure',color='Country',size='Total expenditure')
# Out:
# <div>                            <div id="d57ecf30-7041-403f-9449-69399fef4e94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d57ecf30-7041-403f-9449-69399fef4e94")) {                    Plotly.newPlot(                        "d57ecf30-7041-403f-9449-69399fef4e94",                        [{"hovertemplate":"Country=Zimbabwe\u003cbr\u003eLife expectancy =%{x}\u003cbr\u003eSchooling=%{y}\u003cbr\u003eTotal expenditure=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zimbabwe","marker":{"color":"#636efa","size":[7.1,6.16,6.53,6.52,7.13,6.44,5.12,4.47,4.96,6.26,5.37,6.31,6.69,6.88,6.44,5.9381895280235995],"sizemode":"area","sizeref":0.044000000000000004,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","scene":"scene","showleg
# ...

# %% [markdown]
# ## Life expectancy vs Adult Mortality vs infant deaths

# %%
px.scatter_3d(df.sort_values(by='Year'),y='Adult Mortality',
              x='Life expectancy ',z='infant deaths',
              size='Life expectancy ', color='Country')
# Out:
# <div>                            <div id="c8c7c31e-ee18-4c5f-8758-f03028d6c42b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8c7c31e-ee18-4c5f-8758-f03028d6c42b")) {                    Plotly.newPlot(                        "c8c7c31e-ee18-4c5f-8758-f03028d6c42b",                        [{"hovertemplate":"Country=Zimbabwe\u003cbr\u003eLife expectancy =%{marker.size}\u003cbr\u003eAdult Mortality=%{y}\u003cbr\u003einfant deaths=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Zimbabwe","marker":{"color":"#636efa","size":[46.0,45.3,44.8,44.5,44.3,44.6,45.4,46.6,48.2,50.0,52.4,54.9,56.6,58.0,59.2,67.0],"sizemode":"area","sizeref":0.2225,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","scene":"scene","showlegend":true,"x":[46.0,45.3,
# ...

# %% [markdown]
# ## Life expectancy versus Schooling of countries in every year

# %%
px.scatter(df.sort_values(by='Year'),y='Schooling',x='Life expectancy ',
           animation_frame='Year',animation_group='Country',
           color='Country',size='Life expectancy ',
           title='<b> Life expectancy versus Schooling of countries in every year')
# Out:
# <div>                            <div id="1b51464b-0177-4364-8209-b5222ea58956" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b51464b-0177-4364-8209-b5222ea58956")) {                    Plotly.newPlot(                        "1b51464b-0177-4364-8209-b5222ea58956",                        [{"hovertemplate":"Country=Zimbabwe\u003cbr\u003eYear=2000\u003cbr\u003eLife expectancy =%{marker.size}\u003cbr\u003eSchooling=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Zimbabwe"],"legendgroup":"Zimbabwe","marker":{"color":"#636efa","size":[46.0],"sizemode":"area","sizeref":0.2225,"symbol":"circle"},"mode":"markers","name":"Zimbabwe","orientation":"v","showlegend":true,"x":[46.0],"xaxis":"x","y":[9.8],"yaxis":"y","type":"scatter"},{"hovertemplate":"Cou
# ...

# %% [markdown]
# ## Life Expectancy Versus Adult Mortality in every year

# %%
px.scatter(df.sort_values(by='Year'),y='Adult Mortality',x='Life expectancy ',
           animation_frame='Year',animation_group='Country',color='Country',
           size='Life expectancy ',opacity=0.6,
           title='<b> Life Expectancy Versus Adult Mortality in every year')

# %% [markdown]
# ## Life expectancy versus BMI of Countries in every Year

# %%
px.scatter(df.sort_values(by='Year'),y=' BMI ',x='Life expectancy ',
           animation_frame='Year',animation_group='Country',
           color='Country',size='Life expectancy ',opacity=0.6,
           title='<b> Life expectancy versus BMI of Countries in every Year')

# %% [markdown]
# ## Life Expectancy Versus GDP of Countries in every Year

# %%
px.scatter(df.sort_values(by='Year'),y='GDP',x='Life expectancy ',
           animation_frame='Year',animation_group='Country',
           template='plotly_dark',color='Country',size='Life expectancy ',
           title='<b>Life Expectancy Versus GDP of Countries in every Year')

# %% [markdown]
# ## Build model

# %%
df.describe(include='O')

# %%
df['Country'].unique()

# %%
df['Status'].unique()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
# Country
le.fit(df.Country.drop_duplicates()) 
df.Country = le.transform(df.Country)
# Status
le.fit(df.Status.drop_duplicates()) 
df.Status = le.transform(df.Status)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()
x = df.drop('Life expectancy ',axis=1)
y = df['Life expectancy '].copy()       

linear_reg.fit(x,y)

# %%
y_head = linear_reg.predict(x)

# %%
from sklearn import metrics
print("Mean Absolute Error: ", metrics.mean_absolute_error(y,y_head))
print("Mean Squared Error: ", metrics.mean_squared_error(y,y_head))
print("Root Mean Squared Error: ", np.sqrt(metrics.mean_squared_error(y, y_head)))

# %%
from sklearn.metrics import mean_squared_error, r2_score
print("Estimated accuracy: ", r2_score(y, linear_reg.predict(x)))

# %% [markdown]
# ## Predict

# %%
x.columns

# %%
x.iloc[200]

# %%
linear_reg.predict(x.loc[x.index==200])

# %%
df.loc[df.index==200]
